# %%
# Chain string functions to make a simple series of transformations more clear
text = "   Hello, World! Welcome to Python programming.   "

transformed_text = (
  text.strip()  
  .lower()  
  .replace("hello", "hi")  
  .replace("world", "earth")  
  .replace("python", "awesome Python")  
)

print(transformed_text)
# Out:
# hi, earth! welcome to awesome Python programming.

# %%
words = ['Python', 'is', 'awesome']
sentence = ' '.join(words)
print(sentence)
# Out:
# Python is awesome

# %%
# Use ord to get the ASCII code of a character and chr to get the character from an ASCII code
char = 'A'
ascii_code = ord(char)
print(f"The ASCII code of '{char}' is {ascii_code}")

ascii_code = 66
char = chr(ascii_code)
print(f"The character for ASCII code {ascii_code} is '{char}'")
# Out:
# The ASCII code of 'A' is 65
# The character for ASCII code 66 is 'B'

# %%
formatted_sentence = "The sentence is: '{}' and it contains {} words.".format(sentence, len(words))
print(formatted_sentence)
# Out:
# The sentence is: 'Python is awesome' and it contains 3 words.
