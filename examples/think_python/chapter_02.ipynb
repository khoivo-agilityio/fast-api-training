# %%
import math

math.sqrt(5)
print(math.sqrt(5))

# exercise 2-2
n = m = 1

# %%
import math
# exercise 2-3 part 1
radius = 5

volume = 4/3 * math.pi * radius**3
print(volume)

# exercise 2-3 part 2

x = 420

result = math.cos(x)**2 + math.sin(x)**2
print(round(result,10))

# exercise 2-3 part 3

result_2 = math.e**2
print(result_2)

result_3 = math.pow(math.e, 2)
print(result_3)

result_4 = math.exp(2)
print(result_4)

# exercise 2-4
# Out:
# 523.5987755982989
# 1.0
# 7.3890560989306495
# 7.3890560989306495
# 7.38905609893065
